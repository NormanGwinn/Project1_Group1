# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pathlib as p
import time as t

#directory of source data
hospitalbed_states=pd.read_csv("hospitalbed-states.csv")
hospitalbed_world=pd.read_csv("hospitalbed-world.csv", skiprows=4)
hospitalbed_world
# Out:
#      Country Name Country Code                    Indicator Name  \
# 0           Aruba          ABW  Hospital beds (per 1,000 people)
# 1     Afghanistan          AFG  Hospital beds (per 1,000 people)
# 2          Angola          AGO  Hospital beds (per 1,000 people)
# 3         Albania          ALB  Hospital beds (per 1,000 people)
# 4         Andorra          AND  Hospital beds (per 1,000 people)
# ..            ...          ...                               ...
# 261  South Africa          ZAF  Hospital beds (per 1,000 people)
# 262        Zambia          ZMB  Hospital beds (per 1,000 people)
# 263      Zimbabwe          ZWE  Hospital beds (per 1,000 people)
# 264           NaN          NaN                               NaN
# 265           NaN          NaN                               NaN
#
#      Indicator Code      1960  1961  1962  1963  1964  1965  ...  2010  2011  \
# 0    SH.MED.BEDS.ZS       NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN
# ...

# %%
#statistical summary for number hos pital bed per 1000 person
bed_states=hospitalbed_states["Number of hospital bed per 1000 person"]


bed_states.describe()
# Out:
# count    51.000000
# mean      2.635294
# std       0.750952
# min       1.600000
# 25%       2.100000
# 50%       2.500000
# 75%       3.100000
# max       4.800000
# Name: Number of hospital bed per 1000 person, dtype: float64

# %%
#box plot for number hos pital bed per 1000 person in US states
fig1,ax1=plt.subplots()
ax1.boxplot(bed_states)
plt.show()

# %%
#hospitalbed in world. clean the csv by: 
#1) only select number in 2012
#2) rename and cut column
hospitalbed_world.head(5)
# Out:
#   Country Name Country Code                    Indicator Name  Indicator Code  \
# 0        Aruba          ABW  Hospital beds (per 1,000 people)  SH.MED.BEDS.ZS
# 1  Afghanistan          AFG  Hospital beds (per 1,000 people)  SH.MED.BEDS.ZS
# 2       Angola          AGO  Hospital beds (per 1,000 people)  SH.MED.BEDS.ZS
# 3      Albania          ALB  Hospital beds (per 1,000 people)  SH.MED.BEDS.ZS
# 4      Andorra          AND  Hospital beds (per 1,000 people)  SH.MED.BEDS.ZS
#
#        1960  1961  1962  1963  1964  1965  ...  2010  2011  2012  2013  2014  \
# 0       NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 1  0.170627   NaN   NaN   NaN   NaN   NaN  ...   0.4   0.4   0.5   0.5   0.5
# 2  2.061462   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 3  5.102676   NaN   NaN   NaN   NaN   NaN  ...   3.0   2.6   2.9   2.9   NaN
# 4       NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#    2015  2016  2017  2018  2019
# ...

# %%
help(numeric)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-c5337471ecfb> in <module>
# ----> 1 help(numeric)
#
# NameError: name 'numeric' is not defined

# %%
#boxplot for hospital bed in world

hospitalbed_world["2012"].describe()
#rename the column
# Out:
# count    135.000000
# mean       3.825153
# std        2.693260
# min        0.100000
# 25%        1.700000
# 50%        3.400000
# 75%        5.379743
# max       13.800000
# Name: 2012, dtype: float64

# %%
bed_world=hospitalbed_world["2012"]

fig1,ax1=plt.subplots()
ax1.boxplot(hospitalbed_world["2012"])
plt.show()
# Out:
# C:\Users\ginia\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py:3826: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# C:\Users\ginia\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1316: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# C:\Users\ginia\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1323: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# C:\Users\ginia\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1331: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# C:\Users\ginia\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1332: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],

# %%
country_test= ["china", "italy", "south korea", "iran", "france", "US"]

#value for several countries
china_bed=hospitalbed_world.loc[(hospitalbed_world["Country Name"]=="China")]["2012"]
italy_bed=hospitalbed_world.loc[(hospitalbed_world["Country Name"]=="Italy")]["2012"]
southkorea_bed=hospitalbed_world.loc[(hospitalbed_world["Country Name"]=="Korea, Rep.")]["2012"]
iran_bed=southkorea_bed=hospitalbed_world.loc[(hospitalbed_world["Country Name"]=="Iran, Islamic Rep.")]["2012"]
france_bed=iran_bed=southkorea_bed=hospitalbed_world.loc[(hospitalbed_world["Country Name"]=="France")]["2012"]
US_bed=iran_bed=southkorea_bed=hospitalbed_world.loc[(hospitalbed_world["Country Name"]=="United States")]["2012"]

countries_bed=[china_bed, italy_bed, southkorea_bed, iran_bed, france_bed, US_bed]

iran_bed
# Out:
# 249    2.9
# Name: 2012, dtype: float64

# %%
#dataframe for country and value
hospitalbed_selectedcountries_df=pd.DataFrame({"Selected Countries" : country_test,
                                                "Hospital Bed for Selected countries":countries_bed})


#"a": pd.Series([1, 2, 3], dtype=np.dtype("int32"))

hospitalbed_selectedcountries_df
#datapoints_drug_regimen_df.plot(kind="bar",facecolor="blue")
# Out:
#   Selected Countries    Hospital Bed for Selected countries
# 0              china   38    4.2
# Name: 2012, dtype: float64
# 1              italy  114    3.4
# Name: 2012, dtype: float64
# 2        south korea  249    2.9
# Name: 2012, dtype: float64
# 3               iran  249    2.9
# Name: 2012, dtype: float64
# 4             france   75    6.5
# Name: 2012, dtype: float64
# 5                 US  249    2.9
# Name: 2012, dtype: float64

# %%
#bar chart for selected countries

#hospitalbed_selectedcountries_df.plot(kind="bar",facecolor="blue")
